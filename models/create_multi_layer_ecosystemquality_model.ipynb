# %% [markdown]
# ## Create Multi-Layer NN model using tensorflow
#
# So I can adjust the parameters as I want...

# %%
import sys
sys.path.append("./src") # append to system path

from sklearn import cross_validation
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.decomposition import PCA
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import StandardScaler

import numpy as np
import pandas as pd
import tensorflow as tf

import matplotlib.pyplot as plt
from matplotlib import style
from matplotlib.patches import Rectangle
style.use('ggplot')
# Out:
# /home/runsheng/anaconda2/envs/tensorflow/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def load_lcia_data(descs_p, target_p):
    X = pd.read_csv(descs_p,header=0,index_col=None)
    X = X.fillna(0)
    y = pd.read_csv(target_p,header=0,index_col=None)
    return X.values,y.values

def mre(true_y,pred_y):
    ## Note: does not handle mix 1d representation
    #if _is_1d(y_true): 
    #    y_true, y_pred = _check_1d_array(y_true, y_pred)

    return np.mean(np.abs((true_y - pred_y) / true_y)) * 100

# %% [markdown]
# ### Load Training data
# The training data has 156 chemicals now. The rest 10 chemicals are test data
# We also split the training and validation data here
# We use smaller set (10%) to be the valdiation set (16 chemicals), as the limited size of training chemicals.

# %%
descs_p = '../data/descs/train/descs_Mar08_3839_train.csv'
target_p = '../data/target/train/ecosystemquality_train.csv'
X,y = load_lcia_data(descs_p, target_p)

trn_X, val_X, trn_y, val_y = cross_validation.train_test_split(
    X, y, test_size=0.1, random_state=3)

# %%
print trn_X.shape, trn_y.shape
# Out:
# (140, 3839) (140, 1)

# %% [markdown]
# ### Load Testing data

# %%
descs_tst = '../data/descs/test/descs_Mar08_3839_test.csv'
target_tst = '../data/target/test/ecosystemquality_test.csv'
tst_X,tst_y = load_lcia_data(descs_tst, target_tst)

# %% [markdown]
# ### Data Preprocessing
# Normalization + PCA or Just Normalization

# %% [markdown]
# ### Just Scaler

# %%
## Standard Scaler
this_scaler = StandardScaler()
trn_X = this_scaler.fit_transform(trn_X)
val_X = this_scaler.transform(val_X)
tst_X = this_scaler.transform(tst_X)

# %%
print trn_X.shape
print tst_X.shape
print np.mean(trn_X,0),np.std(trn_X,0)
# Out:
# (140, 3839)
# (10, 3839)
# [ -1.39123274e-16  -7.31161163e-16   5.43612774e-16 ...,   0.00000000e+00
#    2.02219194e-17   8.56457762e-17] [ 1.  1.  1. ...,  0.  1.  1.]

# %% [markdown]
# ##  PCA

# %%
### PCA, don't run them together
# normalize the data first
pca = PCA(n_components = 60)

trn_X = pca.fit_transform(trn_X)
val_X = pca.transform(val_X)
tst_X = pca.transform(tst_X)

# %%
print trn_X.shape, tst_X.shape
print(reduce(lambda x,y:x+y,pca.explained_variance_ratio_))
# Out:
# (140, 60) (10, 60)
# 0.955887655932

# %%
plt.scatter(trn_X[:,0],trn_X[:,1])
plt.scatter(tst_X[:,0],tst_X[:,1])
plt.show()

# %%
n, bins, patches = plt.hist(trn_y, 50, normed=1, facecolor='green', alpha=0.75)
plt.show()

# %% [markdown]
# ### Take the Log Scale of Training Target

# %%
trn_y = np.log(trn_y)
val_y = np.log(val_y)
tst_y = np.log(tst_y)

n, bins, patches = plt.hist(tst_y,50)
plt.show()

# %% [markdown]
# ### Build the model

# %%
def init_weights(shape):
    weights = tf.random_normal(shape,stddev = 0.1)
    return tf.Variable(weights)

def bias_variable(shape):
  initial = tf.constant(0.1, shape=shape)
  return tf.Variable(initial)

num_descs = trn_X.shape[1]
num_target = trn_y.shape[1]

print num_descs,num_target
# Out:
# 60 1

# %%
##### 
##Define model structure

X = tf.placeholder(tf.float32,shape=[None,num_descs])
y = tf.placeholder(tf.float32,shape=[None,num_target])

# First layer
w1 = init_weights((num_descs,512)) 
b1 = bias_variable([512])
l1 = tf.add(tf.matmul(X,w1),b1)
l1 = tf.nn.sigmoid(l1)

# Second layer
w2 = init_weights((512,512)) 
b2 = bias_variable([512])
l2 = tf.add(tf.matmul(l1,w2),b2)
l2 = tf.nn.sigmoid(l2)

# # Third layer
# w3 = init_weights((64,64)) 
# b3 = bias_variable([64])
# l3 = tf.add(tf.matmul(l2,w3),b3)
# l3 = tf.nn.sigmoid(l3)

# # Fourth layer
# w4 = init_weights((64,64)) 
# b4 = bias_variable([64])
# l4 = tf.add(tf.matmul(l3,w4),b4)
# l4 = tf.nn.sigmoid(l4)

# # Fifth layer
# w5 = init_weights((64,64)) 
# b5 = bias_variable([64])
# l5 = tf.add(tf.matmul(l4,w5),b5)
# l5 = tf.nn.sigmoid(l5)

# Output layer
w_out = init_weights((512,num_target))
b_out = bias_variable([num_target])
l_out = tf.matmul(l2,w_out) + b_out #no nonlinarity

pred = l_out

# %%
#static parameters
BATCH_SIZE = 1
BETA = 0.01 #regularization weights

#Define loss and optimizer 
#Add regularization term
# regularizers = tf.nn.l2_loss(w1) + tf.nn.l2_loss(w2) + tf.nn.l2_loss(w3) + tf.nn.l2_loss(w_out)
regularizers = tf.nn.l2_loss(w1) + tf.nn.l2_loss(w2) +tf.nn.l2_loss(w_out)
cost = tf.reduce_mean(tf.square(pred - y) + BETA*regularizers)

#Gridient Descent Optimizer
optimizer = tf.train.AdagradOptimizer(learning_rate = 0.01).minimize(cost)


# Initializing the variables
init = tf.global_variables_initializer()

# %% [markdown]
# ## Training

# %%
#Start Training
costs=[]

#save the model
saver = tf.train.Saver()


with tf.Session() as sess:
    sess.run(init)
    for epoch in range(2000):
        for i in range(0, len(trn_X),BATCH_SIZE):
            _, c = sess.run([optimizer,cost], feed_dict={X:trn_X[i:i+BATCH_SIZE], y:trn_y[i:i+BATCH_SIZE]})
        
        trn_score = r2_score(np.exp(trn_y),np.exp(sess.run(pred, feed_dict={X:trn_X, y:trn_y})))
        val_score = r2_score(np.exp(val_y),np.exp(sess.run(pred, feed_dict={X:val_X, y:val_y})))     
        val_mre = mre(np.exp(val_y),np.exp(sess.run(pred,feed_dict={X:val_X,y:val_y})))
        
        costs.append(val_score)
        if epoch % 1 == 0:
            print("Epoch = %d,Cost = %.2f,Training Accuracy = %.2f, Validation Accuracy = %.2f, Validation MRE =%.2f" % (epoch + 1,c,trn_score,val_score,val_mre))
  
    # final pred on the validation set
    final_pred_val = sess.run(pred,feed_dict={X:val_X})
    # prediction on the testing set
    final_pred_test = sess.run(pred,feed_dict={X:tst_X})
    
    # convert it back 
    
    for (y,y_hat) in zip(np.exp(tst_y),np.exp(final_pred_test)):
        print y,y_hat
    
    
    plt.plot(costs)
    plt.show()
    
    save_path = saver.save(sess, "../nets/tmp/tmp.ckpt")
    print("Model saved in file: %s" % save_path)
# Out:
# Epoch = 1,Cost = 14.00,Training Accuracy = 0.15, Validation Accuracy = -0.35, Validation MRE =100.12
# Epoch = 2,Cost = 13.14,Training Accuracy = 0.05, Validation Accuracy = -0.11, Validation MRE =97.34
# Epoch = 3,Cost = 12.43,Training Accuracy = -0.14, Validation Accuracy = 0.00, Validation MRE =95.01
# Epoch = 4,Cost = 11.77,Training Accuracy = -0.20, Validation Accuracy = 0.04, Validation MRE =91.87
# Epoch = 5,Cost = 11.15,Training Accuracy = -0.19, Validation Accuracy = 0.04, Validation MRE =89.68
# Epoch = 6,Cost = 10.57,Training Accuracy = -0.17, Validation Accuracy = 0.01, Validation MRE =88.83
# Epoch = 7,Cost = 10.02,Training Accuracy = -0.14, Validation Accuracy = -0.01, Validation MRE =88.26
# Epoch = 8,Cost = 9.51,Training Accuracy = -0.11, Validation Accuracy = -0.02, Validation MRE =87.66
# Epoch = 9,Cost = 9.04,Training Accuracy = -0.07, Validation Accuracy = -0.03, Validation MRE =86.86
# Epoch = 10,Cost = 8.59,Training Accuracy = -0.04, Validation Accuracy = -0.02, Validation MRE =85.86
# Epoch = 11,Cost = 8.18,Training Accuracy = 0.00, Validation Accuracy = 0.00, Validation MRE =84.71
# Epoch = 12,Cost = 7.79,Training Accuracy = 0.04, Validation Accuracy = 0.02, Validation MRE =83.45
# Epoch = 13,Cost = 7.43,Training Accuracy = 0.08, Validation Accuracy = 0.05, Validation MRE =82.11
# Epoch = 14,Cost = 7.09,Training Accuracy = 0.12, Validation Accuracy = 0.07, Validation MRE =80.72
# Epoch = 15,Cost = 6.77,Training Accuracy = 0.16, Validation Accuracy = 0.09, Validation MRE =79.64
# Epoch = 16,Cost = 6.48,Training Accuracy = 0.19, Validation Accuracy = 0.12, Validation MRE =78.65
# Epoch = 17,Cost = 6.20,Training Accuracy = 0.22, Validation Accuracy = 0.13, Validation MRE =77.69
# Epoch = 18,Cost = 5.93,Training Accuracy = 0.25, Validation Accuracy = 0.15, Validation MRE =76.75
# Epoch = 19,Cost = 5.69,Training Accuracy = 0.28, Validation Accuracy = 0.16, Validation MRE =75.84
# Epoch = 20,Cost = 5.45,Training Accuracy = 0.30, Validation Accuracy = 0.18, Validation MRE =74.97
# Epoch = 21,Cost = 5.23,Training Accuracy = 0.32, Validation Accuracy = 0.18, Validation MRE =74.14
# Epoch = 22,Cost = 5.02,Training Accuracy = 0.34, Validation Accuracy = 0.19, Validation MRE =73.34
# Epoch = 23,Cost = 4.83,Training Accuracy = 0.36, Validation Accuracy = 0.20, Validation MRE =72.59
# Epoch = 24,Cost = 4.64,Training Accuracy = 0.38, Validation Accuracy = 0.20, Validation MRE =71.89
# Epoch = 25,Cost = 4.47,Training Accuracy = 0.39, Validation Accuracy = 0.20, Validation MRE =71.24
# Epoch = 26,Cost = 4.30,Training Accuracy = 0.41, Validation Accuracy = 0.21, Validation MRE =71.01
# Epoch = 27,Cost = 4.14,Training Accuracy = 0.42, Validation Accuracy = 0.21, Validation MRE =70.79
# Epoch = 28,Cost = 3.99,Training Accuracy = 0.43, Validation Accuracy = 0.21, Validation MRE =70.58
# Epoch = 29,Cost = 3.85,Training Accuracy = 0.44, Validation Accuracy = 0.21, Validation MRE =70.39
# Epoch = 30,Cost = 3.71,Training Accuracy = 0.45, Validation Accuracy = 0.21, Validation MRE =70.21
# Epoch = 31,Cost = 3.59,Training Accuracy = 0.46, Validation Accuracy = 0.20, Validation MRE =70.04
# Epoch = 32,Cost = 3.46,Training Accuracy = 0.47, Validation Accuracy = 0.20, Validation MRE =69.88
# Epoch = 33,Cost = 3.35,Training Accuracy = 0.47, Validation Accuracy = 0.20, Validation MRE =69.75
# Epoch = 34,Cost = 3.24,Training Accuracy = 0.48, Validation Accuracy = 0.20, Validation MRE =69.63
# Epoch = 35,Cost = 3.13,Training Accuracy = 0.49, Validation Accuracy = 0.20, Validation MRE =69.52
# Epoch = 36,Cost = 3.03,Training Accuracy = 0.49, Validation Accuracy = 0.20, Validation MRE =69.43
# Epoch = 37,Cost = 2.94,Training Accuracy = 0.50, Validation Accuracy = 0.19, Validation MRE =69.35
# Epoch = 38,Cost = 2.85,Training Accuracy = 0.50, Validation Accuracy = 0.19, Validation MRE =69.29
# Epoch = 39,Cost = 2.76,Training Accuracy = 0.51, Validation Accuracy = 0.19, Validation MRE =69.24
# Epoch = 40,Cost = 2.68,Training Accuracy = 0.51, Validation Accuracy = 0.19, Validation MRE =69.20
# Epoch = 41,Cost = 2.60,Training Accuracy = 0.51, Validation Accuracy = 0.18, Validation MRE =69.18
# Epoch = 42,Cost = 2.52,Training Accuracy = 0.52, Validation Accuracy = 0.18, Validation MRE =69.17
# Epoch = 43,Cost = 2.45,Training Accuracy = 0.52, Validation Accuracy = 0.18, Validation MRE =69.18
# Epoch = 44,Cost = 2.38,Training Accuracy = 0.52, Validation Accuracy = 0.18, Validation MRE =69.19
# Epoch = 45,Cost = 2.31,Training Accuracy = 0.52, Validation Accuracy = 0.17, Validation MRE =69.22
# Epoch = 46,Cost = 2.25,Training Accuracy = 0.52, Validation Accuracy = 0.17, Validation MRE =69.25
# Epoch = 47,Cost = 2.19,Training Accuracy = 0.53, Validation Accuracy = 0.17, Validation MRE =69.30
# Epoch = 48,Cost = 2.13,Training Accuracy = 0.53, Validation Accuracy = 0.16, Validation MRE =69.36
# Epoch = 49,Cost = 2.08,Training Accuracy = 0.53, Validation Accuracy = 0.16, Validation MRE =69.42
# Epoch = 50,Cost = 2.02,Training Accuracy = 0.53, Validation Accuracy = 0.16, Validation MRE =69.50
# Epoch = 51,Cost = 1.97,Training Accuracy = 0.53, Validation Accuracy = 0.15, Validation MRE =69.58
# Epoch = 52,Cost = 1.92,Training Accuracy = 0.53, Validation Accuracy = 0.15, Validation MRE =69.67
# Epoch = 53,Cost = 1.87,Training Accuracy = 0.53, Validation Accuracy = 0.14, Validation MRE =69.77
# Epoch = 54,Cost = 1.83,Training Accuracy = 0.53, Validation Accuracy = 0.14, Validation MRE =69.87
# Epoch = 55,Cost = 1.78,Training Accuracy = 0.53, Validation Accuracy = 0.13, Validation MRE =69.98
# Epoch = 56,Cost = 1.74,Training Accuracy = 0.53, Validation Accuracy = 0.13, Validation MRE =70.09
# Epoch = 57,Cost = 1.70,Training Accuracy = 0.53, Validation Accuracy = 0.12, Validation MRE =70.22
# Epoch = 58,Cost = 1.66,Training Accuracy = 0.53, Validation Accuracy = 0.12, Validation MRE =70.34
# Epoch = 59,Cost = 1.62,Training Accuracy = 0.53, Validation Accuracy = 0.11, Validation MRE =70.47
# Epoch = 60,Cost = 1.58,Training Accuracy = 0.53, Validation Accuracy = 0.11, Validation MRE =70.61
# Epoch = 61,Cost = 1.55,Training Accuracy = 0.52, Validation Accuracy = 0.10, Validation MRE =70.75
# Epoch = 62,Cost = 1.51,Training Accuracy = 0.52, Validation Accuracy = 0.10, Validation MRE =70.89
# Epoch = 63,Cost = 1.48,Training Accuracy = 0.52, Validation Accuracy = 0.09, Validation MRE =71.03
# Epoch = 64,Cost = 1.45,Training Accuracy = 0.52, Validation Accuracy = 0.08, Validation MRE =71.18
# Epoch = 65,Cost = 1.42,Training Accuracy = 0.52, Validation Accuracy = 0.08, Validation MRE =71.34
# Epoch = 66,Cost = 1.39,Training Accuracy = 0.52, Validation Accuracy = 0.07, Validation MRE =71.49
# Epoch = 67,Cost = 1.36,Training Accuracy = 0.51, Validation Accuracy = 0.06, Validation MRE =71.65
# Epoch = 68,Cost = 1.33,Training Accuracy = 0.51, Validation Accuracy = 0.06, Validation MRE =71.81
# Epoch = 69,Cost = 1.30,Training Accuracy = 0.51, Validation Accuracy = 0.05, Validation MRE =71.97
# Epoch = 70,Cost = 1.28,Training Accuracy = 0.51, Validation Accuracy = 0.04, Validation MRE =72.13
# Epoch = 71,Cost = 1.25,Training Accuracy = 0.50, Validation Accuracy = 0.03, Validation MRE =72.30
# Epoch = 72,Cost = 1.23,Training Accuracy = 0.50, Validation Accuracy = 0.02, Validation MRE =72.46
# Epoch = 73,Cost = 1.20,Training Accuracy = 0.50, Validation Accuracy = 0.02, Validation MRE =72.63
# Epoch = 74,Cost = 1.18,Training Accuracy = 0.50, Validation Accuracy = 0.01, Validation MRE =72.80
# Epoch = 75,Cost = 1.16,Training Accuracy = 0.50, Validation Accuracy = -0.00, Validation MRE =72.97
# Epoch = 76,Cost = 1.14,Training Accuracy = 0.49, Validation Accuracy = -0.01, Validation MRE =73.15
# Epoch = 77,Cost = 1.12,Training Accuracy = 0.49, Validation Accuracy = -0.02, Validation MRE =73.32
# Epoch = 78,Cost = 1.10,Training Accuracy = 0.49, Validation Accuracy = -0.03, Validation MRE =73.49
# Epoch = 79,Cost = 1.08,Training Accuracy = 0.49, Validation Accuracy = -0.04, Validation MRE =73.67
# Epoch = 80,Cost = 1.06,Training Accuracy = 0.48, Validation Accuracy = -0.05, Validation MRE =73.84
# Epoch = 81,Cost = 1.04,Training Accuracy = 0.48, Validation Accuracy = -0.06, Validation MRE =74.02
# Epoch = 82,Cost = 1.02,Training Accuracy = 0.48, Validation Accuracy = -0.07, Validation MRE =74.20
# Epoch = 83,Cost = 1.00,Training Accuracy = 0.47, Validation Accuracy = -0.08, Validation MRE =74.38
# Epoch = 84,Cost = 0.99,Training Accuracy = 0.47, Validation Accuracy = -0.09, Validation MRE =74.55
# Epoch = 85,Cost = 0.97,Training Accuracy = 0.47, Validation Accuracy = -0.10, Validation MRE =74.73
# Epoch = 86,Cost = 0.96,Training Accuracy = 0.47, Validation Accuracy = -0.11, Validation MRE =74.91
# Epoch = 87,Cost = 0.94,Training Accuracy = 0.46, Validation Accuracy = -0.12, Validation MRE =75.09
# Epoch = 88,Cost = 0.92,Training Accuracy = 0.46, Validation Accuracy = -0.13, Validation MRE =75.27
# Epoch = 89,Cost = 0.91,Training Accuracy = 0.46, Validation Accuracy = -0.14, Validation MRE =75.45
# Epoch = 90,Cost = 0.90,Training Accuracy = 0.46, Validation Accuracy = -0.16, Validation MRE =75.63
# Epoch = 91,Cost = 0.88,Training Accuracy = 0.45, Validation Accuracy = -0.17, Validation MRE =75.80
# Epoch = 92,Cost = 0.87,Training Accuracy = 0.45, Validation Accuracy = -0.18, Validation MRE =75.98
# Epoch = 93,Cost = 0.86,Training Accuracy = 0.45, Validation Accuracy = -0.19, Validation MRE =76.16
# Epoch = 94,Cost = 0.84,Training Accuracy = 0.45, Validation Accuracy = -0.20, Validation MRE =76.34
# Epoch = 95,Cost = 0.83,Training Accuracy = 0.44, Validation Accuracy = -0.22, Validation MRE =76.51
# Epoch = 96,Cost = 0.82,Training Accuracy = 0.44, Validation Accuracy = -0.23, Validation MRE =76.69
# Epoch = 97,Cost = 0.81,Training Accuracy = 0.44, Validation Accuracy = -0.24, Validation MRE =76.86
# Epoch = 98,Cost = 0.80,Training Accuracy = 0.44, Validation Accuracy = -0.25, Validation MRE =77.04
# Epoch = 99,Cost = 0.78,Training Accuracy = 0.43, Validation Accuracy = -0.27, Validation MRE =77.21
# Epoch = 100,Cost = 0.77,Training Accuracy = 0.43, Validation Accuracy = -0.28, Validation MRE =77.39
# Epoch = 101,Cost = 0.76,Training Accuracy = 0.43, Validation Accuracy = -0.29, Validation MRE =77.56
# Epoch = 102,Cost = 0.75,Training Accuracy = 0.43, Validation Accuracy = -0.30, Validation MRE =77.73
# Epoch = 103,Cost = 0.74,Training Accuracy = 0.43, Validation Accuracy = -0.32, Validation MRE =77.90
# Epoch = 104,Cost = 0.73,Training Accuracy = 0.42, Validation Accuracy = -0.33, Validation MRE =78.08
# Epoch = 105,Cost = 0.72,Training Accuracy = 0.42, Validation Accuracy = -0.34, Validation MRE =78.23
# Epoch = 106,Cost = 0.71,Training Accuracy = 0.42, Validation Accuracy = -0.36, Validation MRE =78.43
# Epoch = 107,Cost = 0.70,Training Accuracy = 0.42, Validation Accuracy = -0.37, Validation MRE =78.58
# Epoch = 108,Cost = 0.70,Training Accuracy = 0.41, Validation Accuracy = -0.38, Validation MRE =78.74
# Epoch = 109,Cost = 0.69,Training Accuracy = 0.42, Validation Accuracy = -0.40, Validation MRE =78.93
# Epoch = 110,Cost = 0.68,Training Accuracy = 0.40, Validation Accuracy = -0.41, Validation MRE =79.08
# Epoch = 111,Cost = 0.67,Training Accuracy = 0.42, Validation Accuracy = -0.43, Validation MRE =79.21
# Epoch = 112,Cost = 0.66,Training Accuracy = 0.40, Validation Accuracy = -0.45, Validation MRE =79.47
# Epoch = 113,Cost = 0.65,Training Accuracy = 0.41, Validation Accuracy = -0.45, Validation MRE =79.50
# Epoch = 114,Cost = 0.65,Training Accuracy = 0.41, Validation Accuracy = -0.46, Validation MRE =79.75
# Epoch = 115,Cost = 0.64,Training Accuracy = 0.40, Validation Accuracy = -0.51, Validation MRE =79.95
# Epoch = 116,Cost = 0.64,Training Accuracy = 0.39, Validation Accuracy = -0.47, Validation MRE =79.94
# Epoch = 117,Cost = 0.62,Training Accuracy = 0.43, Validation Accuracy = -0.54, Validation MRE =80.26
# Epoch = 118,Cost = 0.62,Training Accuracy = 0.34, Validation Accuracy = -0.53, Validation MRE =80.50
# Epoch = 119,Cost = 0.61,Training Accuracy = 0.45, Validation Accuracy = -0.52, Validation MRE =80.13
# Epoch = 120,Cost = 0.61,Training Accuracy = 0.36, Validation Accuracy = -0.58, Validation MRE =81.08
# Epoch = 121,Cost = 0.59,Training Accuracy = 0.36, Validation Accuracy = -0.59, Validation MRE =80.64
# Epoch = 122,Cost = 0.62,Training Accuracy = 0.37, Validation Accuracy = -0.49, Validation MRE =80.59
# Epoch = 123,Cost = 0.56,Training Accuracy = 0.40, Validation Accuracy = -0.80, Validation MRE =82.01
# Epoch = 124,Cost = 0.62,Training Accuracy = 0.22, Validation Accuracy = -0.45, Validation MRE =80.20
# Epoch = 125,Cost = 0.55,Training Accuracy = 0.51, Validation Accuracy = -0.67, Validation MRE =81.52
# Epoch = 126,Cost = 0.60,Training Accuracy = 0.17, Validation Accuracy = -0.64, Validation MRE =81.35
# Epoch = 127,Cost = 0.54,Training Accuracy = 0.31, Validation Accuracy = -0.52, Validation MRE =80.52
# Epoch = 128,Cost = 0.59,Training Accuracy = 0.29, Validation Accuracy = -0.56, Validation MRE =80.55
# Epoch = 129,Cost = 0.52,Training Accuracy = -0.04, Validation Accuracy = -0.98, Validation MRE =84.38
# Epoch = 130,Cost = 0.59,Training Accuracy = 0.40, Validation Accuracy = -0.33, Validation MRE =77.41
# Epoch = 131,Cost = 0.52,Training Accuracy = 0.36, Validation Accuracy = -0.98, Validation MRE =85.57
# Epoch = 132,Cost = 0.56,Training Accuracy = 0.29, Validation Accuracy = -0.54, Validation MRE =79.77
# Epoch = 133,Cost = 0.52,Training Accuracy = 0.41, Validation Accuracy = -0.59, Validation MRE =82.25
# Epoch = 134,Cost = 0.54,Training Accuracy = 0.39, Validation Accuracy = -0.71, Validation MRE =81.83
# Epoch = 135,Cost = 0.51,Training Accuracy = 0.24, Validation Accuracy = -0.77, Validation MRE =83.59
# Epoch = 136,Cost = 0.53,Training Accuracy = 0.44, Validation Accuracy = -0.60, Validation MRE =81.23
# Epoch = 137,Cost = 0.50,Training Accuracy = 0.35, Validation Accuracy = -0.91, Validation MRE =84.82
# Epoch = 138,Cost = 0.52,Training Accuracy = 0.37, Validation Accuracy = -0.71, Validation MRE =82.14
# Epoch = 139,Cost = 0.50,Training Accuracy = 0.41, Validation Accuracy = -0.77, Validation MRE =83.58
# Epoch = 140,Cost = 0.50,Training Accuracy = 0.39, Validation Accuracy = -0.85, Validation MRE =83.47
# Epoch = 141,Cost = 0.49,Training Accuracy = 0.38, Validation Accuracy = -0.80, Validation MRE =83.49
# Epoch = 142,Cost = 0.49,Training Accuracy = 0.42, Validation Accuracy = -0.82, Validation MRE =83.31
# Epoch = 143,Cost = 0.48,Training Accuracy = 0.38, Validation Accuracy = -0.91, Validation MRE =84.23
# Epoch = 144,Cost = 0.48,Training Accuracy = 0.40, Validation Accuracy = -0.83, Validation MRE =83.34
# Epoch = 145,Cost = 0.48,Training Accuracy = 0.41, Validation Accuracy = -0.90, Validation MRE =84.03
# Epoch = 146,Cost = 0.47,Training Accuracy = 0.40, Validation Accuracy = -0.92, Validation MRE =83.98
# Epoch = 147,Cost = 0.47,Training Accuracy = 0.41, Validation Accuracy = -0.89, Validation MRE =83.87
# Epoch = 148,Cost = 0.47,Training Accuracy = 0.41, Validation Accuracy = -0.94, Validation MRE =84.12
# Epoch = 149,Cost = 0.46,Training Accuracy = 0.40, Validation Accuracy = -0.96, Validation MRE =84.29
# Epoch = 150,Cost = 0.46,Training Accuracy = 0.42, Validation Accuracy = -0.94, Validation MRE =84.09
# Epoch = 151,Cost = 0.46,Training Accuracy = 0.41, Validation Accuracy = -0.99, Validation MRE =84.50
# Epoch = 152,Cost = 0.45,Training Accuracy = 0.41, Validation Accuracy = -0.99, Validation MRE =84.47
# Epoch = 153,Cost = 0.45,Training Accuracy = 0.42, Validation Accuracy = -0.99, Validation MRE =84.52
# Epoch = 154,Cost = 0.45,Training Accuracy = 0.41, Validation Accuracy = -1.03, Validation MRE =84.78
# Epoch = 155,Cost = 0.44,Training Accuracy = 0.41, Validation Accuracy = -1.03, Validation MRE =84.81
# Epoch = 156,Cost = 0.44,Training Accuracy = 0.42, Validation Accuracy = -1.04, Validation MRE =84.89
# Epoch = 157,Cost = 0.44,Training Accuracy = 0.41, Validation Accuracy = -1.08, Validation MRE =85.15
# Epoch = 158,Cost = 0.43,Training Accuracy = 0.41, Validation Accuracy = -1.08, Validation MRE =85.15
# Epoch = 159,Cost = 0.43,Training Accuracy = 0.42, Validation Accuracy = -1.10, Validation MRE =85.31
# Epoch = 160,Cost = 0.43,Training Accuracy = 0.41, Validation Accuracy = -1.12, Validation MRE =85.49
# Epoch = 161,Cost = 0.42,Training Accuracy = 0.41, Validation Accuracy = -1.12, Validation MRE =85.53
# Epoch = 162,Cost = 0.42,Training Accuracy = 0.42, Validation Accuracy = -1.15, Validation MRE =85.71
# Epoch = 163,Cost = 0.42,Training Accuracy = 0.41, Validation Accuracy = -1.17, Validation MRE =85.86
# Epoch = 164,Cost = 0.42,Training Accuracy = 0.42, Validation Accuracy = -1.17, Validation MRE =85.91
# Epoch = 165,Cost = 0.41,Training Accuracy = 0.41, Validation Accuracy = -1.20, Validation MRE =86.10
# Epoch = 166,Cost = 0.41,Training Accuracy = 0.41, Validation Accuracy = -1.21, Validation MRE =86.22
# Epoch = 167,Cost = 0.41,Training Accuracy = 0.42, Validation Accuracy = -1.23, Validation MRE =86.30
# Epoch = 168,Cost = 0.41,Training Accuracy = 0.41, Validation Accuracy = -1.25, Validation MRE =86.48
# Epoch = 169,Cost = 0.40,Training Accuracy = 0.41, Validation Accuracy = -1.26, Validation MRE =86.58
# Epoch = 170,Cost = 0.40,Training Accuracy = 0.42, Validation Accuracy = -1.28, Validation MRE =86.69
# Epoch = 171,Cost = 0.40,Training Accuracy = 0.42, Validation Accuracy = -1.30, Validation MRE =86.85
# Epoch = 172,Cost = 0.40,Training Accuracy = 0.42, Validation Accuracy = -1.31, Validation MRE =86.94
# Epoch = 173,Cost = 0.39,Training Accuracy = 0.42, Validation Accuracy = -1.33, Validation MRE =87.06
# Epoch = 174,Cost = 0.39,Training Accuracy = 0.42, Validation Accuracy = -1.35, Validation MRE =87.21
# Epoch = 175,Cost = 0.39,Training Accuracy = 0.42, Validation Accuracy = -1.36, Validation MRE =87.29
# Epoch = 176,Cost = 0.39,Training Accuracy = 0.42, Validation Accuracy = -1.38, Validation MRE =87.42
# Epoch = 177,Cost = 0.38,Training Accuracy = 0.42, Validation Accuracy = -1.40, Validation MRE =87.55
# Epoch = 178,Cost = 0.38,Training Accuracy = 0.42, Validation Accuracy = -1.41, Validation MRE =87.64
# Epoch = 179,Cost = 0.38,Training Accuracy = 0.42, Validation Accuracy = -1.43, Validation MRE =87.78
# Epoch = 180,Cost = 0.38,Training Accuracy = 0.42, Validation Accuracy = -1.45, Validation MRE =87.89
# Epoch = 181,Cost = 0.38,Training Accuracy = 0.42, Validation Accuracy = -1.46, Validation MRE =87.98
# Epoch = 182,Cost = 0.37,Training Accuracy = 0.42, Validation Accuracy = -1.48, Validation MRE =88.12
# Epoch = 183,Cost = 0.37,Training Accuracy = 0.42, Validation Accuracy = -1.50, Validation MRE =88.21
# Epoch = 184,Cost = 0.37,Training Accuracy = 0.42, Validation Accuracy = -1.51, Validation MRE =88.32
# Epoch = 185,Cost = 0.37,Training Accuracy = 0.42, Validation Accuracy = -1.53, Validation MRE =88.44
# Epoch = 186,Cost = 0.37,Training Accuracy = 0.42, Validation Accuracy = -1.55, Validation MRE =88.54
# Epoch = 187,Cost = 0.36,Training Accuracy = 0.42, Validation Accuracy = -1.56, Validation MRE =88.65
# Epoch = 188,Cost = 0.36,Training Accuracy = 0.42, Validation Accuracy = -1.58, Validation MRE =88.76
# Epoch = 189,Cost = 0.36,Training Accuracy = 0.43, Validation Accuracy = -1.60, Validation MRE =88.85
# Epoch = 190,Cost = 0.36,Training Accuracy = 0.43, Validation Accuracy = -1.61, Validation MRE =88.97
# Epoch = 191,Cost = 0.36,Training Accuracy = 0.43, Validation Accuracy = -1.63, Validation MRE =89.08
# Epoch = 192,Cost = 0.35,Training Accuracy = 0.43, Validation Accuracy = -1.65, Validation MRE =89.17
# Epoch = 193,Cost = 0.35,Training Accuracy = 0.43, Validation Accuracy = -1.66, Validation MRE =89.28
# Epoch = 194,Cost = 0.35,Training Accuracy = 0.43, Validation Accuracy = -1.68, Validation MRE =89.39
# Epoch = 195,Cost = 0.35,Training Accuracy = 0.43, Validation Accuracy = -1.70, Validation MRE =89.48
# Epoch = 196,Cost = 0.35,Training Accuracy = 0.43, Validation Accuracy = -1.71, Validation MRE =89.60
# Epoch = 197,Cost = 0.34,Training Accuracy = 0.43, Validation Accuracy = -1.73, Validation MRE =89.69
# Epoch = 198,Cost = 0.34,Training Accuracy = 0.43, Validation Accuracy = -1.75, Validation MRE =89.79
# Epoch = 199,Cost = 0.34,Training Accuracy = 0.43, Validation Accuracy = -1.76, Validation MRE =89.90
# Epoch = 200,Cost = 0.34,Training Accuracy = 0.43, Validation Accuracy = -1.78, Validation MRE =89.99
# Epoch = 201,Cost = 0.34,Training Accuracy = 0.43, Validation Accuracy = -1.80, Validation MRE =90.10
# Epoch = 202,Cost = 0.34,Training Accuracy = 0.43, Validation Accuracy = -1.81, Validation MRE =90.20
# Epoch = 203,Cost = 0.33,Training Accuracy = 0.43, Validation Accuracy = -1.83, Validation MRE =90.29
# Epoch = 204,Cost = 0.33,Training Accuracy = 0.44, Validation Accuracy = -1.85, Validation MRE =90.40
# Epoch = 205,Cost = 0.33,Training Accuracy = 0.44, Validation Accuracy = -1.86, Validation MRE =90.50
# Epoch = 206,Cost = 0.33,Training Accuracy = 0.44, Validation Accuracy = -1.88, Validation MRE =90.59
# Epoch = 207,Cost = 0.33,Training Accuracy = 0.44, Validation Accuracy = -1.90, Validation MRE =90.70
# Epoch = 208,Cost = 0.33,Training Accuracy = 0.44, Validation Accuracy = -1.91, Validation MRE =90.80
# Epoch = 209,Cost = 0.33,Training Accuracy = 0.44, Validation Accuracy = -1.93, Validation MRE =90.89
# Epoch = 210,Cost = 0.32,Training Accuracy = 0.44, Validation Accuracy = -1.95, Validation MRE =90.99
# Epoch = 211,Cost = 0.32,Training Accuracy = 0.44, Validation Accuracy = -1.96, Validation MRE =91.09
# Epoch = 212,Cost = 0.32,Training Accuracy = 0.44, Validation Accuracy = -1.98, Validation MRE =91.18
# Epoch = 213,Cost = 0.32,Training Accuracy = 0.44, Validation Accuracy = -2.00, Validation MRE =91.29
# Epoch = 214,Cost = 0.32,Training Accuracy = 0.44, Validation Accuracy = -2.01, Validation MRE =91.37
# Epoch = 215,Cost = 0.32,Training Accuracy = 0.44, Validation Accuracy = -2.03, Validation MRE =91.47
# Epoch = 216,Cost = 0.32,Training Accuracy = 0.44, Validation Accuracy = -2.05, Validation MRE =91.57
# Epoch = 217,Cost = 0.31,Training Accuracy = 0.44, Validation Accuracy = -2.06, Validation MRE =91.66
# Epoch = 218,Cost = 0.31,Training Accuracy = 0.44, Validation Accuracy = -2.08, Validation MRE =91.76
# Epoch = 219,Cost = 0.31,Training Accuracy = 0.44, Validation Accuracy = -2.10, Validation MRE =91.86
# Epoch = 220,Cost = 0.31,Training Accuracy = 0.45, Validation Accuracy = -2.11, Validation MRE =91.94
# Epoch = 221,Cost = 0.31,Training Accuracy = 0.45, Validation Accuracy = -2.13, Validation MRE =92.04
# Epoch = 222,Cost = 0.31,Training Accuracy = 0.45, Validation Accuracy = -2.15, Validation MRE =92.13
# Epoch = 223,Cost = 0.31,Training Accuracy = 0.45, Validation Accuracy = -2.16, Validation MRE =92.22
# Epoch = 224,Cost = 0.31,Training Accuracy = 0.45, Validation Accuracy = -2.18, Validation MRE =92.32
# Epoch = 225,Cost = 0.30,Training Accuracy = 0.45, Validation Accuracy = -2.20, Validation MRE =92.41
# Epoch = 226,Cost = 0.30,Training Accuracy = 0.45, Validation Accuracy = -2.21, Validation MRE =92.50
# Epoch = 227,Cost = 0.30,Training Accuracy = 0.45, Validation Accuracy = -2.23, Validation MRE =92.59
# Epoch = 228,Cost = 0.30,Training Accuracy = 0.45, Validation Accuracy = -2.24, Validation MRE =92.68
# Epoch = 229,Cost = 0.30,Training Accuracy = 0.45, Validation Accuracy = -2.26, Validation MRE =92.77
# Epoch = 230,Cost = 0.30,Training Accuracy = 0.45, Validation Accuracy = -2.28, Validation MRE =92.86
# Epoch = 231,Cost = 0.30,Training Accuracy = 0.45, Validation Accuracy = -2.29, Validation MRE =92.94
# Epoch = 232,Cost = 0.30,Training Accuracy = 0.45, Validation Accuracy = -2.31, Validation MRE =93.04
# Epoch = 233,Cost = 0.30,Training Accuracy = 0.45, Validation Accuracy = -2.33, Validation MRE =93.12
# Epoch = 234,Cost = 0.29,Training Accuracy = 0.45, Validation Accuracy = -2.34, Validation MRE =93.21
# Epoch = 235,Cost = 0.29,Training Accuracy = 0.45, Validation Accuracy = -2.36, Validation MRE =93.30
# Epoch = 236,Cost = 0.29,Training Accuracy = 0.46, Validation Accuracy = -2.38, Validation MRE =93.38
# Epoch = 237,Cost = 0.29,Training Accuracy = 0.46, Validation Accuracy = -2.39, Validation MRE =93.47
# Epoch = 238,Cost = 0.29,Training Accuracy = 0.46, Validation Accuracy = -2.41, Validation MRE =93.56
# Epoch = 239,Cost = 0.29,Training Accuracy = 0.46, Validation Accuracy = -2.42, Validation MRE =93.64
# Epoch = 240,Cost = 0.29,Training Accuracy = 0.46, Validation Accuracy = -2.44, Validation MRE =93.72
# Epoch = 241,Cost = 0.29,Training Accuracy = 0.46, Validation Accuracy = -2.46, Validation MRE =93.81
# Epoch = 242,Cost = 0.29,Training Accuracy = 0.46, Validation Accuracy = -2.47, Validation MRE =93.89
# Epoch = 243,Cost = 0.29,Training Accuracy = 0.46, Validation Accuracy = -2.49, Validation MRE =93.97
# Epoch = 244,Cost = 0.28,Training Accuracy = 0.46, Validation Accuracy = -2.51, Validation MRE =94.06
# Epoch = 245,Cost = 0.28,Training Accuracy = 0.46, Validation Accuracy = -2.52, Validation MRE =94.13
# Epoch = 246,Cost = 0.28,Training Accuracy = 0.46, Validation Accuracy = -2.54, Validation MRE =94.22
# Epoch = 247,Cost = 0.28,Training Accuracy = 0.46, Validation Accuracy = -2.55, Validation MRE =94.30
# Epoch = 248,Cost = 0.28,Training Accuracy = 0.46, Validation Accuracy = -2.57, Validation MRE =94.37
# Epoch = 249,Cost = 0.28,Training Accuracy = 0.46, Validation Accuracy = -2.58, Validation MRE =94.46
# Epoch = 250,Cost = 0.28,Training Accuracy = 0.46, Validation Accuracy = -2.60, Validation MRE =94.54
# Epoch = 251,Cost = 0.28,Training Accuracy = 0.46, Validation Accuracy = -2.62, Validation MRE =94.61
# Epoch = 252,Cost = 0.28,Training Accuracy = 0.46, Validation Accuracy = -2.63, Validation MRE =94.70
# Epoch = 253,Cost = 0.28,Training Accuracy = 0.47, Validation Accuracy = -2.65, Validation MRE =94.77
# Epoch = 254,Cost = 0.28,Training Accuracy = 0.47, Validation Accuracy = -2.66, Validation MRE =94.85
# Epoch = 255,Cost = 0.27,Training Accuracy = 0.47, Validation Accuracy = -2.68, Validation MRE =94.93
# Epoch = 256,Cost = 0.27,Training Accuracy = 0.47, Validation Accuracy = -2.69, Validation MRE =95.00
# Epoch = 257,Cost = 0.27,Training Accuracy = 0.47, Validation Accuracy = -2.71, Validation MRE =95.08
# Epoch = 258,Cost = 0.27,Training Accuracy = 0.47, Validation Accuracy = -2.73, Validation MRE =95.15
# Epoch = 259,Cost = 0.27,Training Accuracy = 0.47, Validation Accuracy = -2.74, Validation MRE =95.22
# Epoch = 260,Cost = 0.27,Training Accuracy = 0.47, Validation Accuracy = -2.76, Validation MRE =95.30
# Epoch = 261,Cost = 0.27,Training Accuracy = 0.47, Validation Accuracy = -2.77, Validation MRE =95.38
# Epoch = 262,Cost = 0.27,Training Accuracy = 0.47, Validation Accuracy = -2.79, Validation MRE =95.45
# Epoch = 263,Cost = 0.27,Training Accuracy = 0.47, Validation Accuracy = -2.80, Validation MRE =95.53
# Epoch = 264,Cost = 0.27,Training Accuracy = 0.47, Validation Accuracy = -2.82, Validation MRE =95.59
# Epoch = 265,Cost = 0.27,Training Accuracy = 0.47, Validation Accuracy = -2.83, Validation MRE =95.67
# Epoch = 266,Cost = 0.27,Training Accuracy = 0.47, Validation Accuracy = -2.85, Validation MRE =95.74
# Epoch = 267,Cost = 0.27,Training Accuracy = 0.47, Validation Accuracy = -2.86, Validation MRE =95.81
# Epoch = 268,Cost = 0.26,Training Accuracy = 0.47, Validation Accuracy = -2.88, Validation MRE =95.88
# Epoch = 269,Cost = 0.26,Training Accuracy = 0.47, Validation Accuracy = -2.89, Validation MRE =95.95
# Epoch = 270,Cost = 0.26,Training Accuracy = 0.48, Validation Accuracy = -2.91, Validation MRE =96.02
# Epoch = 271,Cost = 0.26,Training Accuracy = 0.48, Validation Accuracy = -2.92, Validation MRE =96.09
# Epoch = 272,Cost = 0.26,Training Accuracy = 0.48, Validation Accuracy = -2.94, Validation MRE =96.16
# Epoch = 273,Cost = 0.26,Training Accuracy = 0.48, Validation Accuracy = -2.95, Validation MRE =96.22
# Epoch = 274,Cost = 0.26,Training Accuracy = 0.48, Validation Accuracy = -2.97, Validation MRE =96.30
# Epoch = 275,Cost = 0.26,Training Accuracy = 0.48, Validation Accuracy = -2.98, Validation MRE =96.36
# Epoch = 276,Cost = 0.26,Training Accuracy = 0.48, Validation Accuracy = -3.00, Validation MRE =96.43
# Epoch = 277,Cost = 0.26,Training Accuracy = 0.48, Validation Accuracy = -3.01, Validation MRE =96.50
# Epoch = 278,Cost = 0.26,Training Accuracy = 0.48, Validation Accuracy = -3.03, Validation MRE =96.56
# Epoch = 279,Cost = 0.26,Training Accuracy = 0.48, Validation Accuracy = -3.04, Validation MRE =96.63
# Epoch = 280,Cost = 0.26,Training Accuracy = 0.48, Validation Accuracy = -3.06, Validation MRE =96.70
# Epoch = 281,Cost = 0.26,Training Accuracy = 0.48, Validation Accuracy = -3.07, Validation MRE =96.76
# Epoch = 282,Cost = 0.26,Training Accuracy = 0.48, Validation Accuracy = -3.08, Validation MRE =96.83
# Epoch = 283,Cost = 0.25,Training Accuracy = 0.48, Validation Accuracy = -3.10, Validation MRE =96.89
# Epoch = 284,Cost = 0.25,Training Accuracy = 0.48, Validation Accuracy = -3.11, Validation MRE =96.95
# Epoch = 285,Cost = 0.25,Training Accuracy = 0.48, Validation Accuracy = -3.13, Validation MRE =97.02
# Epoch = 286,Cost = 0.25,Training Accuracy = 0.48, Validation Accuracy = -3.14, Validation MRE =97.08
# Epoch = 287,Cost = 0.25,Training Accuracy = 0.49, Validation Accuracy = -3.16, Validation MRE =97.14
# Epoch = 288,Cost = 0.25,Training Accuracy = 0.49, Validation Accuracy = -3.17, Validation MRE =97.21
# Epoch = 289,Cost = 0.25,Training Accuracy = 0.49, Validation Accuracy = -3.18, Validation MRE =97.27
# Epoch = 290,Cost = 0.25,Training Accuracy = 0.49, Validation Accuracy = -3.20, Validation MRE =97.33
# Epoch = 291,Cost = 0.25,Training Accuracy = 0.49, Validation Accuracy = -3.21, Validation MRE =97.40
# Epoch = 292,Cost = 0.25,Training Accuracy = 0.49, Validation Accuracy = -3.23, Validation MRE =97.45
# Epoch = 293,Cost = 0.25,Training Accuracy = 0.49, Validation Accuracy = -3.24, Validation MRE =97.52
# Epoch = 294,Cost = 0.25,Training Accuracy = 0.49, Validation Accuracy = -3.26, Validation MRE =97.58
# Epoch = 295,Cost = 0.25,Training Accuracy = 0.49, Validation Accuracy = -3.27, Validation MRE =97.64
# Epoch = 296,Cost = 0.25,Training Accuracy = 0.49, Validation Accuracy = -3.28, Validation MRE =97.70
# Epoch = 297,Cost = 0.25,Training Accuracy = 0.49, Validation Accuracy = -3.30, Validation MRE =97.76
# Epoch = 298,Cost = 0.25,Training Accuracy = 0.49, Validation Accuracy = -3.31, Validation MRE =97.81
# Epoch = 299,Cost = 0.25,Training Accuracy = 0.49, Validation Accuracy = -3.32, Validation MRE =97.88
# Epoch = 300,Cost = 0.25,Training Accuracy = 0.49, Validation Accuracy = -3.34, Validation MRE =97.93
# Epoch = 301,Cost = 0.24,Training Accuracy = 0.49, Validation Accuracy = -3.35, Validation MRE =97.99
# Epoch = 302,Cost = 0.24,Training Accuracy = 0.49, Validation Accuracy = -3.37, Validation MRE =98.05
# Epoch = 303,Cost = 0.24,Training Accuracy = 0.49, Validation Accuracy = -3.38, Validation MRE =98.11
# Epoch = 304,Cost = 0.24,Training Accuracy = 0.49, Validation Accuracy = -3.39, Validation MRE =98.16
# Epoch = 305,Cost = 0.24,Training Accuracy = 0.49, Validation Accuracy = -3.41, Validation MRE =98.22
# Epoch = 306,Cost = 0.24,Training Accuracy = 0.50, Validation Accuracy = -3.42, Validation MRE =98.28
# Epoch = 307,Cost = 0.24,Training Accuracy = 0.50, Validation Accuracy = -3.43, Validation MRE =98.33
# Epoch = 308,Cost = 0.24,Training Accuracy = 0.50, Validation Accuracy = -3.45, Validation MRE =98.39
# Epoch = 309,Cost = 0.24,Training Accuracy = 0.50, Validation Accuracy = -3.46, Validation MRE =98.44
# Epoch = 310,Cost = 0.24,Training Accuracy = 0.50, Validation Accuracy = -3.47, Validation MRE =98.50
# Epoch = 311,Cost = 0.24,Training Accuracy = 0.50, Validation Accuracy = -3.49, Validation MRE =98.56
# Epoch = 312,Cost = 0.24,Training Accuracy = 0.50, Validation Accuracy = -3.50, Validation MRE =98.61
# Epoch = 313,Cost = 0.24,Training Accuracy = 0.50, Validation Accuracy = -3.51, Validation MRE =98.67
# Epoch = 314,Cost = 0.24,Training Accuracy = 0.50, Validation Accuracy = -3.53, Validation MRE =98.72
# Epoch = 315,Cost = 0.24,Training Accuracy = 0.50, Validation Accuracy = -3.54, Validation MRE =98.77
# Epoch = 316,Cost = 0.24,Training Accuracy = 0.50, Validation Accuracy = -3.55, Validation MRE =98.83
# Epoch = 317,Cost = 0.24,Training Accuracy = 0.50, Validation Accuracy = -3.57, Validation MRE =98.88
# Epoch = 318,Cost = 0.24,Training Accuracy = 0.50, Validation Accuracy = -3.58, Validation MRE =98.93
# Epoch = 319,Cost = 0.24,Training Accuracy = 0.50, Validation Accuracy = -3.59, Validation MRE =98.98
# Epoch = 320,Cost = 0.24,Training Accuracy = 0.50, Validation Accuracy = -3.60, Validation MRE =99.04
# Epoch = 321,Cost = 0.24,Training Accuracy = 0.50, Validation Accuracy = -3.62, Validation MRE =99.09
# Epoch = 322,Cost = 0.23,Training Accuracy = 0.50, Validation Accuracy = -3.63, Validation MRE =99.14
# Epoch = 323,Cost = 0.23,Training Accuracy = 0.50, Validation Accuracy = -3.64, Validation MRE =99.19
# Epoch = 324,Cost = 0.23,Training Accuracy = 0.50, Validation Accuracy = -3.66, Validation MRE =99.24
# Epoch = 325,Cost = 0.23,Training Accuracy = 0.50, Validation Accuracy = -3.67, Validation MRE =99.29
# Epoch = 326,Cost = 0.23,Training Accuracy = 0.51, Validation Accuracy = -3.68, Validation MRE =99.34
# Epoch = 327,Cost = 0.23,Training Accuracy = 0.51, Validation Accuracy = -3.69, Validation MRE =99.39
# Epoch = 328,Cost = 0.23,Training Accuracy = 0.51, Validation Accuracy = -3.71, Validation MRE =99.44
# Epoch = 329,Cost = 0.23,Training Accuracy = 0.51, Validation Accuracy = -3.72, Validation MRE =99.49
# Epoch = 330,Cost = 0.23,Training Accuracy = 0.51, Validation Accuracy = -3.73, Validation MRE =99.54
# Epoch = 331,Cost = 0.23,Training Accuracy = 0.51, Validation Accuracy = -3.74, Validation MRE =99.59
# Epoch = 332,Cost = 0.23,Training Accuracy = 0.51, Validation Accuracy = -3.76, Validation MRE =99.64
# Epoch = 333,Cost = 0.23,Training Accuracy = 0.51, Validation Accuracy = -3.77, Validation MRE =99.69
# Epoch = 334,Cost = 0.23,Training Accuracy = 0.51, Validation Accuracy = -3.78, Validation MRE =99.74
# Epoch = 335,Cost = 0.23,Training Accuracy = 0.51, Validation Accuracy = -3.79, Validation MRE =99.79
# Epoch = 336,Cost = 0.23,Training Accuracy = 0.51, Validation Accuracy = -3.81, Validation MRE =99.83
# Epoch = 337,Cost = 0.23,Training Accuracy = 0.51, Validation Accuracy = -3.82, Validation MRE =99.88
# Epoch = 338,Cost = 0.23,Training Accuracy = 0.51, Validation Accuracy = -3.83, Validation MRE =99.93
# Epoch = 339,Cost = 0.23,Training Accuracy = 0.51, Validation Accuracy = -3.84, Validation MRE =99.98
# Epoch = 340,Cost = 0.23,Training Accuracy = 0.51, Validation Accuracy = -3.85, Validation MRE =100.02
# Epoch = 341,Cost = 0.23,Training Accuracy = 0.51, Validation Accuracy = -3.87, Validation MRE =100.07
# Epoch = 342,Cost = 0.23,Training Accuracy = 0.51, Validation Accuracy = -3.88, Validation MRE =100.12
# Epoch = 343,Cost = 0.23,Training Accuracy = 0.51, Validation Accuracy = -3.89, Validation MRE =100.16
# Epoch = 344,Cost = 0.23,Training Accuracy = 0.51, Validation Accuracy = -3.90, Validation MRE =100.21
# Epoch = 345,Cost = 0.23,Training Accuracy = 0.51, Validation Accuracy = -3.91, Validation MRE =100.25
# Epoch = 346,Cost = 0.23,Training Accuracy = 0.51, Validation Accuracy = -3.93, Validation MRE =100.30
# Epoch = 347,Cost = 0.23,Training Accuracy = 0.51, Validation Accuracy = -3.94, Validation MRE =100.34
# Epoch = 348,Cost = 0.22,Training Accuracy = 0.51, Validation Accuracy = -3.95, Validation MRE =100.39
# Epoch = 349,Cost = 0.22,Training Accuracy = 0.52, Validation Accuracy = -3.96, Validation MRE =100.43
# Epoch = 350,Cost = 0.22,Training Accuracy = 0.52, Validation Accuracy = -3.97, Validation MRE =100.48
# Epoch = 351,Cost = 0.22,Training Accuracy = 0.52, Validation Accuracy = -3.99, Validation MRE =100.52
# Epoch = 352,Cost = 0.22,Training Accuracy = 0.52, Validation Accuracy = -4.00, Validation MRE =100.56
# Epoch = 353,Cost = 0.22,Training Accuracy = 0.52, Validation Accuracy = -4.01, Validation MRE =100.61
# Epoch = 354,Cost = 0.22,Training Accuracy = 0.52, Validation Accuracy = -4.02, Validation MRE =100.65
# Epoch = 355,Cost = 0.22,Training Accuracy = 0.52, Validation Accuracy = -4.03, Validation MRE =100.70
# Epoch = 356,Cost = 0.22,Training Accuracy = 0.52, Validation Accuracy = -4.04, Validation MRE =100.74
# Epoch = 357,Cost = 0.22,Training Accuracy = 0.52, Validation Accuracy = -4.06, Validation MRE =100.78
# Epoch = 358,Cost = 0.22,Training Accuracy = 0.52, Validation Accuracy = -4.07, Validation MRE =100.82
# Epoch = 359,Cost = 0.22,Training Accuracy = 0.52, Validation Accuracy = -4.08, Validation MRE =100.87
# Epoch = 360,Cost = 0.22,Training Accuracy = 0.52, Validation Accuracy = -4.09, Validation MRE =100.91
# Epoch = 361,Cost = 0.22,Training Accuracy = 0.52, Validation Accuracy = -4.10, Validation MRE =100.95
# Epoch = 362,Cost = 0.22,Training Accuracy = 0.52, Validation Accuracy = -4.11, Validation MRE =100.99
# Epoch = 363,Cost = 0.22,Training Accuracy = 0.52, Validation Accuracy = -4.12, Validation MRE =101.03
# Epoch = 364,Cost = 0.22,Training Accuracy = 0.52, Validation Accuracy = -4.13, Validation MRE =101.07
# Epoch = 365,Cost = 0.22,Training Accuracy = 0.52, Validation Accuracy = -4.15, Validation MRE =101.11
# Epoch = 366,Cost = 0.22,Training Accuracy = 0.52, Validation Accuracy = -4.16, Validation MRE =101.16
# Epoch = 367,Cost = 0.22,Training Accuracy = 0.52, Validation Accuracy = -4.17, Validation MRE =101.20
# Epoch = 368,Cost = 0.22,Training Accuracy = 0.52, Validation Accuracy = -4.18, Validation MRE =101.24
# Epoch = 369,Cost = 0.22,Training Accuracy = 0.52, Validation Accuracy = -4.19, Validation MRE =101.28
# Epoch = 370,Cost = 0.22,Training Accuracy = 0.52, Validation Accuracy = -4.20, Validation MRE =101.32
# Epoch = 371,Cost = 0.22,Training Accuracy = 0.52, Validation Accuracy = -4.21, Validation MRE =101.36
# Epoch = 372,Cost = 0.22,Training Accuracy = 0.52, Validation Accuracy = -4.22, Validation MRE =101.40
# Epoch = 373,Cost = 0.22,Training Accuracy = 0.53, Validation Accuracy = -4.23, Validation MRE =101.44
# Epoch = 374,Cost = 0.22,Training Accuracy = 0.53, Validation Accuracy = -4.25, Validation MRE =101.48
# Epoch = 375,Cost = 0.22,Training Accuracy = 0.53, Validation Accuracy = -4.26, Validation MRE =101.51
# Epoch = 376,Cost = 0.22,Training Accuracy = 0.53, Validation Accuracy = -4.27, Validation MRE =101.55
# Epoch = 377,Cost = 0.22,Training Accuracy = 0.53, Validation Accuracy = -4.28, Validation MRE =101.59
# Epoch = 378,Cost = 0.22,Training Accuracy = 0.53, Validation Accuracy = -4.29, Validation MRE =101.63
# Epoch = 379,Cost = 0.22,Training Accuracy = 0.53, Validation Accuracy = -4.30, Validation MRE =101.67
# Epoch = 380,Cost = 0.22,Training Accuracy = 0.53, Validation Accuracy = -4.31, Validation MRE =101.71
# Epoch = 381,Cost = 0.21,Training Accuracy = 0.53, Validation Accuracy = -4.32, Validation MRE =101.75
# Epoch = 382,Cost = 0.21,Training Accuracy = 0.53, Validation Accuracy = -4.33, Validation MRE =101.78
# Epoch = 383,Cost = 0.21,Training Accuracy = 0.53, Validation Accuracy = -4.34, Validation MRE =101.82
# Epoch = 384,Cost = 0.21,Training Accuracy = 0.53, Validation Accuracy = -4.35, Validation MRE =101.86
# Epoch = 385,Cost = 0.21,Training Accuracy = 0.53, Validation Accuracy = -4.36, Validation MRE =101.89
# Epoch = 386,Cost = 0.21,Training Accuracy = 0.53, Validation Accuracy = -4.37, Validation MRE =101.93
# Epoch = 387,Cost = 0.21,Training Accuracy = 0.53, Validation Accuracy = -4.39, Validation MRE =101.97
# Epoch = 388,Cost = 0.21,Training Accuracy = 0.53, Validation Accuracy = -4.40, Validation MRE =102.01
# Epoch = 389,Cost = 0.21,Training Accuracy = 0.53, Validation Accuracy = -4.41, Validation MRE =102.04
# Epoch = 390,Cost = 0.21,Training Accuracy = 0.53, Validation Accuracy = -4.42, Validation MRE =102.08
# Epoch = 391,Cost = 0.21,Training Accuracy = 0.53, Validation Accuracy = -4.43, Validation MRE =102.12
# Epoch = 392,Cost = 0.21,Training Accuracy = 0.53, Validation Accuracy = -4.44, Validation MRE =102.15
# Epoch = 393,Cost = 0.21,Training Accuracy = 0.53, Validation Accuracy = -4.45, Validation MRE =102.19
# Epoch = 394,Cost = 0.21,Training Accuracy = 0.53, Validation Accuracy = -4.46, Validation MRE =102.22
# Epoch = 395,Cost = 0.21,Training Accuracy = 0.53, Validation Accuracy = -4.47, Validation MRE =102.26
# Epoch = 396,Cost = 0.21,Training Accuracy = 0.53, Validation Accuracy = -4.48, Validation MRE =102.29
# Epoch = 397,Cost = 0.21,Training Accuracy = 0.53, Validation Accuracy = -4.49, Validation MRE =102.33
# Epoch = 398,Cost = 0.21,Training Accuracy = 0.53, Validation Accuracy = -4.50, Validation MRE =102.36
# Epoch = 399,Cost = 0.21,Training Accuracy = 0.53, Validation Accuracy = -4.51, Validation MRE =102.40
# Epoch = 400,Cost = 0.21,Training Accuracy = 0.53, Validation Accuracy = -4.52, Validation MRE =102.43
# Epoch = 401,Cost = 0.21,Training Accuracy = 0.54, Validation Accuracy = -4.53, Validation MRE =102.47
# Epoch = 402,Cost = 0.21,Training Accuracy = 0.54, Validation Accuracy = -4.54, Validation MRE =102.50
# Epoch = 403,Cost = 0.21,Training Accuracy = 0.54, Validation Accuracy = -4.55, Validation MRE =102.54
# Epoch = 404,Cost = 0.21,Training Accuracy = 0.54, Validation Accuracy = -4.56, Validation MRE =102.57
# Epoch = 405,Cost = 0.21,Training Accuracy = 0.54, Validation Accuracy = -4.57, Validation MRE =102.61
# Epoch = 406,Cost = 0.21,Training Accuracy = 0.54, Validation Accuracy = -4.58, Validation MRE =102.64
# Epoch = 407,Cost = 0.21,Training Accuracy = 0.54, Validation Accuracy = -4.59, Validation MRE =102.67
# Epoch = 408,Cost = 0.21,Training Accuracy = 0.54, Validation Accuracy = -4.60, Validation MRE =102.71
# Epoch = 409,Cost = 0.21,Training Accuracy = 0.54, Validation Accuracy = -4.61, Validation MRE =102.74
# Epoch = 410,Cost = 0.21,Training Accuracy = 0.54, Validation Accuracy = -4.62, Validation MRE =102.78
# Epoch = 411,Cost = 0.21,Training Accuracy = 0.54, Validation Accuracy = -4.63, Validation MRE =102.81
# Epoch = 412,Cost = 0.21,Training Accuracy = 0.54, Validation Accuracy = -4.64, Validation MRE =102.84
# Epoch = 413,Cost = 0.21,Training Accuracy = 0.54, Validation Accuracy = -4.65, Validation MRE =102.87
# Epoch = 414,Cost = 0.21,Training Accuracy = 0.54, Validation Accuracy = -4.66, Validation MRE =102.91
# Epoch = 415,Cost = 0.21,Training Accuracy = 0.54, Validation Accuracy = -4.67, Validation MRE =102.94
# Epoch = 416,Cost = 0.21,Training Accuracy = 0.54, Validation Accuracy = -4.68, Validation MRE =102.97
# Epoch = 417,Cost = 0.21,Training Accuracy = 0.54, Validation Accuracy = -4.69, Validation MRE =103.00
# Epoch = 418,Cost = 0.21,Training Accuracy = 0.54, Validation Accuracy = -4.70, Validation MRE =103.04
# Epoch = 419,Cost = 0.21,Training Accuracy = 0.54, Validation Accuracy = -4.71, Validation MRE =103.07
# Epoch = 420,Cost = 0.21,Training Accuracy = 0.54, Validation Accuracy = -4.72, Validation MRE =103.10
# Epoch = 421,Cost = 0.21,Training Accuracy = 0.54, Validation Accuracy = -4.73, Validation MRE =103.13
# Epoch = 422,Cost = 0.21,Training Accuracy = 0.54, Validation Accuracy = -4.74, Validation MRE =103.17
# Epoch = 423,Cost = 0.21,Training Accuracy = 0.54, Validation Accuracy = -4.75, Validation MRE =103.20
# Epoch = 424,Cost = 0.21,Training Accuracy = 0.54, Validation Accuracy = -4.76, Validation MRE =103.23
# Epoch = 425,Cost = 0.20,Training Accuracy = 0.54, Validation Accuracy = -4.77, Validation MRE =103.26
# Epoch = 426,Cost = 0.20,Training Accuracy = 0.54, Validation Accuracy = -4.78, Validation MRE =103.29
# Epoch = 427,Cost = 0.20,Training Accuracy = 0.54, Validation Accuracy = -4.79, Validation MRE =103.32
# Epoch = 428,Cost = 0.20,Training Accuracy = 0.54, Validation Accuracy = -4.80, Validation MRE =103.35
# Epoch = 429,Cost = 0.20,Training Accuracy = 0.54, Validation Accuracy = -4.81, Validation MRE =103.39
# Epoch = 430,Cost = 0.20,Training Accuracy = 0.54, Validation Accuracy = -4.82, Validation MRE =103.42
# Epoch = 431,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -4.83, Validation MRE =103.45
# Epoch = 432,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -4.84, Validation MRE =103.48
# Epoch = 433,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -4.84, Validation MRE =103.51
# Epoch = 434,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -4.85, Validation MRE =103.54
# Epoch = 435,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -4.86, Validation MRE =103.57
# Epoch = 436,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -4.87, Validation MRE =103.60
# Epoch = 437,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -4.88, Validation MRE =103.63
# Epoch = 438,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -4.89, Validation MRE =103.66
# Epoch = 439,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -4.90, Validation MRE =103.69
# Epoch = 440,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -4.91, Validation MRE =103.72
# Epoch = 441,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -4.92, Validation MRE =103.75
# Epoch = 442,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -4.93, Validation MRE =103.78
# Epoch = 443,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -4.94, Validation MRE =103.81
# Epoch = 444,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -4.95, Validation MRE =103.84
# Epoch = 445,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -4.96, Validation MRE =103.87
# Epoch = 446,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -4.97, Validation MRE =103.90
# Epoch = 447,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -4.98, Validation MRE =103.93
# Epoch = 448,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -4.99, Validation MRE =103.96
# Epoch = 449,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -4.99, Validation MRE =103.98
# Epoch = 450,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -5.00, Validation MRE =104.01
# Epoch = 451,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -5.01, Validation MRE =104.04
# Epoch = 452,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -5.02, Validation MRE =104.07
# Epoch = 453,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -5.03, Validation MRE =104.10
# Epoch = 454,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -5.04, Validation MRE =104.13
# Epoch = 455,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -5.05, Validation MRE =104.16
# Epoch = 456,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -5.06, Validation MRE =104.19
# Epoch = 457,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -5.07, Validation MRE =104.21
# Epoch = 458,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -5.08, Validation MRE =104.24
# Epoch = 459,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -5.09, Validation MRE =104.27
# Epoch = 460,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -5.09, Validation MRE =104.30
# Epoch = 461,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -5.10, Validation MRE =104.33
# Epoch = 462,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -5.11, Validation MRE =104.35
# Epoch = 463,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -5.12, Validation MRE =104.38
# Epoch = 464,Cost = 0.20,Training Accuracy = 0.55, Validation Accuracy = -5.13, Validation MRE =104.41
# Epoch = 465,Cost = 0.20,Training Accuracy = 0.56, Validation Accuracy = -5.14, Validation MRE =104.44
# Epoch = 466,Cost = 0.20,Training Accuracy = 0.56, Validation Accuracy = -5.15, Validation MRE =104.47
# Epoch = 467,Cost = 0.20,Training Accuracy = 0.56, Validation Accuracy = -5.16, Validation MRE =104.49
# Epoch = 468,Cost = 0.20,Training Accuracy = 0.56, Validation Accuracy = -5.17, Validation MRE =104.52
# Epoch = 469,Cost = 0.20,Training Accuracy = 0.56, Validation Accuracy = -5.18, Validation MRE =104.55
# Epoch = 470,Cost = 0.20,Training Accuracy = 0.56, Validation Accuracy = -5.18, Validation MRE =104.58
# Epoch = 471,Cost = 0.20,Training Accuracy = 0.56, Validation Accuracy = -5.19, Validation MRE =104.60
# Epoch = 472,Cost = 0.20,Training Accuracy = 0.56, Validation Accuracy = -5.20, Validation MRE =104.63
# Epoch = 473,Cost = 0.20,Training Accuracy = 0.56, Validation Accuracy = -5.21, Validation MRE =104.66
# Epoch = 474,Cost = 0.20,Training Accuracy = 0.56, Validation Accuracy = -5.22, Validation MRE =104.68
# Epoch = 475,Cost = 0.20,Training Accuracy = 0.56, Validation Accuracy = -5.23, Validation MRE =104.71
# ...
# Epoch = 1850,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.25, Validation MRE =103.20
# Epoch = 1851,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.25, Validation MRE =103.20
# Epoch = 1852,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.25, Validation MRE =103.19
# Epoch = 1853,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.25, Validation MRE =103.19
# Epoch = 1854,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.25, Validation MRE =103.18
# Epoch = 1855,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.25, Validation MRE =103.18
# Epoch = 1856,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.25, Validation MRE =103.17
# Epoch = 1857,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.25, Validation MRE =103.17
# Epoch = 1858,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.25, Validation MRE =103.17
# Epoch = 1859,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.25, Validation MRE =103.16
# Epoch = 1860,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.24, Validation MRE =103.16
# Epoch = 1861,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.24, Validation MRE =103.15
# Epoch = 1862,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.24, Validation MRE =103.15
# Epoch = 1863,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.24, Validation MRE =103.14
# Epoch = 1864,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.24, Validation MRE =103.14
# Epoch = 1865,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.24, Validation MRE =103.14
# Epoch = 1866,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.24, Validation MRE =103.13
# Epoch = 1867,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.24, Validation MRE =103.13
# Epoch = 1868,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.24, Validation MRE =103.12
# Epoch = 1869,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.24, Validation MRE =103.12
# Epoch = 1870,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.23, Validation MRE =103.11
# Epoch = 1871,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.23, Validation MRE =103.11
# Epoch = 1872,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.23, Validation MRE =103.11
# Epoch = 1873,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.23, Validation MRE =103.10
# Epoch = 1874,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.23, Validation MRE =103.10
# Epoch = 1875,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.23, Validation MRE =103.09
# Epoch = 1876,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.23, Validation MRE =103.09
# Epoch = 1877,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.23, Validation MRE =103.09
# Epoch = 1878,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.23, Validation MRE =103.08
# Epoch = 1879,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.23, Validation MRE =103.08
# Epoch = 1880,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.22, Validation MRE =103.07
# Epoch = 1881,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.22, Validation MRE =103.07
# Epoch = 1882,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.22, Validation MRE =103.06
# Epoch = 1883,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.22, Validation MRE =103.06
# Epoch = 1884,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.22, Validation MRE =103.06
# Epoch = 1885,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.22, Validation MRE =103.05
# Epoch = 1886,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.22, Validation MRE =103.05
# Epoch = 1887,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.22, Validation MRE =103.04
# Epoch = 1888,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.22, Validation MRE =103.04
# Epoch = 1889,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.22, Validation MRE =103.04
# Epoch = 1890,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.21, Validation MRE =103.03
# Epoch = 1891,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.21, Validation MRE =103.03
# Epoch = 1892,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.21, Validation MRE =103.02
# Epoch = 1893,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.21, Validation MRE =103.02
# Epoch = 1894,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.21, Validation MRE =103.02
# Epoch = 1895,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.21, Validation MRE =103.01
# Epoch = 1896,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.21, Validation MRE =103.01
# Epoch = 1897,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.21, Validation MRE =103.00
# Epoch = 1898,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.21, Validation MRE =103.00
# Epoch = 1899,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.21, Validation MRE =103.00
# Epoch = 1900,Cost = 0.16,Training Accuracy = 0.71, Validation Accuracy = -6.20, Validation MRE =102.99
# Epoch = 1901,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.20, Validation MRE =102.99
# Epoch = 1902,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.20, Validation MRE =102.98
# Epoch = 1903,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.20, Validation MRE =102.98
# Epoch = 1904,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.20, Validation MRE =102.98
# Epoch = 1905,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.20, Validation MRE =102.97
# Epoch = 1906,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.20, Validation MRE =102.97
# Epoch = 1907,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.20, Validation MRE =102.96
# Epoch = 1908,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.20, Validation MRE =102.96
# Epoch = 1909,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.20, Validation MRE =102.96
# Epoch = 1910,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.20, Validation MRE =102.95
# Epoch = 1911,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.19, Validation MRE =102.95
# Epoch = 1912,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.19, Validation MRE =102.94
# Epoch = 1913,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.19, Validation MRE =102.94
# Epoch = 1914,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.19, Validation MRE =102.94
# Epoch = 1915,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.19, Validation MRE =102.93
# Epoch = 1916,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.19, Validation MRE =102.93
# Epoch = 1917,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.19, Validation MRE =102.92
# Epoch = 1918,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.19, Validation MRE =102.92
# Epoch = 1919,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.19, Validation MRE =102.92
# Epoch = 1920,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.19, Validation MRE =102.91
# Epoch = 1921,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.19, Validation MRE =102.91
# Epoch = 1922,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.18, Validation MRE =102.91
# Epoch = 1923,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.18, Validation MRE =102.90
# Epoch = 1924,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.18, Validation MRE =102.90
# Epoch = 1925,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.18, Validation MRE =102.89
# Epoch = 1926,Cost = 0.15,Training Accuracy = 0.71, Validation Accuracy = -6.18, Validation MRE =102.89
# Epoch = 1927,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.18, Validation MRE =102.89
# Epoch = 1928,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.18, Validation MRE =102.88
# Epoch = 1929,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.18, Validation MRE =102.88
# Epoch = 1930,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.18, Validation MRE =102.87
# Epoch = 1931,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.18, Validation MRE =102.87
# Epoch = 1932,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.18, Validation MRE =102.87
# Epoch = 1933,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.17, Validation MRE =102.86
# Epoch = 1934,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.17, Validation MRE =102.86
# Epoch = 1935,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.17, Validation MRE =102.86
# Epoch = 1936,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.17, Validation MRE =102.85
# Epoch = 1937,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.17, Validation MRE =102.85
# Epoch = 1938,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.17, Validation MRE =102.84
# Epoch = 1939,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.17, Validation MRE =102.84
# Epoch = 1940,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.17, Validation MRE =102.84
# Epoch = 1941,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.17, Validation MRE =102.83
# Epoch = 1942,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.17, Validation MRE =102.83
# Epoch = 1943,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.17, Validation MRE =102.83
# Epoch = 1944,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.17, Validation MRE =102.82
# Epoch = 1945,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.16, Validation MRE =102.82
# Epoch = 1946,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.16, Validation MRE =102.82
# Epoch = 1947,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.16, Validation MRE =102.81
# Epoch = 1948,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.16, Validation MRE =102.81
# Epoch = 1949,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.16, Validation MRE =102.80
# Epoch = 1950,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.16, Validation MRE =102.80
# Epoch = 1951,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.16, Validation MRE =102.80
# Epoch = 1952,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.16, Validation MRE =102.79
# Epoch = 1953,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.16, Validation MRE =102.79
# Epoch = 1954,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.16, Validation MRE =102.79
# Epoch = 1955,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.16, Validation MRE =102.78
# Epoch = 1956,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.16, Validation MRE =102.78
# Epoch = 1957,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.15, Validation MRE =102.78
# Epoch = 1958,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.15, Validation MRE =102.77
# Epoch = 1959,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.15, Validation MRE =102.77
# Epoch = 1960,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.15, Validation MRE =102.76
# Epoch = 1961,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.15, Validation MRE =102.76
# Epoch = 1962,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.15, Validation MRE =102.76
# Epoch = 1963,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.15, Validation MRE =102.75
# Epoch = 1964,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.15, Validation MRE =102.75
# Epoch = 1965,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.15, Validation MRE =102.75
# Epoch = 1966,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.15, Validation MRE =102.74
# Epoch = 1967,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.15, Validation MRE =102.74
# Epoch = 1968,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.15, Validation MRE =102.74
# Epoch = 1969,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.14, Validation MRE =102.73
# Epoch = 1970,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.14, Validation MRE =102.73
# Epoch = 1971,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.14, Validation MRE =102.73
# Epoch = 1972,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.14, Validation MRE =102.72
# Epoch = 1973,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.14, Validation MRE =102.72
# Epoch = 1974,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.14, Validation MRE =102.71
# Epoch = 1975,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.14, Validation MRE =102.71
# Epoch = 1976,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.14, Validation MRE =102.71
# Epoch = 1977,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.14, Validation MRE =102.70
# Epoch = 1978,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.14, Validation MRE =102.70
# Epoch = 1979,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.14, Validation MRE =102.70
# Epoch = 1980,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.14, Validation MRE =102.69
# Epoch = 1981,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.13, Validation MRE =102.69
# Epoch = 1982,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.13, Validation MRE =102.69
# Epoch = 1983,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.13, Validation MRE =102.68
# Epoch = 1984,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.13, Validation MRE =102.68
# Epoch = 1985,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.13, Validation MRE =102.68
# Epoch = 1986,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.13, Validation MRE =102.67
# Epoch = 1987,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.13, Validation MRE =102.67
# Epoch = 1988,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.13, Validation MRE =102.67
# Epoch = 1989,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.13, Validation MRE =102.66
# Epoch = 1990,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.13, Validation MRE =102.66
# Epoch = 1991,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.13, Validation MRE =102.66
# Epoch = 1992,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.13, Validation MRE =102.65
# Epoch = 1993,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.13, Validation MRE =102.65
# Epoch = 1994,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.12, Validation MRE =102.65
# Epoch = 1995,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.12, Validation MRE =102.64
# Epoch = 1996,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.12, Validation MRE =102.64
# Epoch = 1997,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.12, Validation MRE =102.64
# Epoch = 1998,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.12, Validation MRE =102.63
# Epoch = 1999,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.12, Validation MRE =102.63
# Epoch = 2000,Cost = 0.15,Training Accuracy = 0.72, Validation Accuracy = -6.12, Validation MRE =102.63
# [ 0.00012772] [ 0.0001958]
# [ 0.00012991] [  6.17874321e-05]
# [ 0.00011437] [ 0.0007259]
# [ 0.00040355] [ 0.00033472]
# [ 0.00036248] [ 0.00034228]
# [  6.37000000e-05] [  3.08904891e-05]
# [  8.74000000e-05] [ 0.00241655]
# [  1.17000000e-05] [  5.13436971e-05]
# [  9.31000000e-05] [ 0.00010058]
# [  2.41000000e-05] [  2.86030827e-05]
# Model saved in file: ../nets/tmp/tmp.ckpt

# %%
# Convert the value back, remember only run this once 
tst_y = np.exp(tst_y) 
final_pred_test = np.exp(final_pred_test)

# %%
MRE_this = mre(tst_y, final_pred_test)
R2_this = r2_score(tst_y, final_pred_test)
print R2_this
MRE_label = 'MRE: ' + str(round(MRE_this,2))

fig = plt.figure()
ax = fig.add_subplot(111)
est = plt.plot(tst_y, final_pred_test,'o', label='estimated values')

max_val = max(max(tst_y),max(final_pred_test))
plt.ylim([0,max_val])
plt.xlim([0,max_val])

thisLine = plt.plot(np.append(0,max_val), np.append(0,max_val), label='perfect prediction line')

plt.plot([],[],linewidth=0, label=MRE_label)
plt.legend(loc='upper left')
plt.show()
# Out:
# -16.2731319912
